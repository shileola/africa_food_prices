# %% [markdown]
# # PYTHON MINI PROJECT

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

print('done')
# Out:
# done

# %%
df = pd.read_csv("C:/Users/USER/Desktop/africa_food_prices.csv")

# %%
df
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
df.shape
# Out:
# (956779, 19)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
#        'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
#        'mp_commoditysource'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# Unnamed: 0
# country_id
# country
# state_id
# state
# market_id
# market
# produce_id
# produce
# currency_id
# currency
# pt_id
# market_type
# um_unit_id
# quantity
# month
# year
# price
# mp_commoditysource

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %% [markdown]
# ## DATA CLEANING PROCESS

# %%
df
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
df = df.rename(columns={
     df.columns[0] : 'row_id',
     df.columns[6] : 'state name',
     df.columns[8] : 'product & type'
})

# %%
df
# Out:
#          row_id  country_id   country  state_id     state  market_id  \
# 0         15427         4.0   Algeria       344     Alger       1794
# 1         15428         4.0   Algeria       344     Alger       1794
# 2         15429         4.0   Algeria       344     Alger       1794
# 3         15430         4.0   Algeria       344     Alger       1794
# 4         15431         4.0   Algeria       344     Alger       1794
# ...         ...         ...       ...       ...       ...        ...
# 956774  2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775  2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776  2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777  2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778  2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#         state name  produce_id           product & type  currency_id currency  \
# ...

# %%
df.drop(columns=['row_id','country_id','pt_id','state_id','currency_id','state','um_unit_id','mp_commoditysource','produce_id','market_id'],inplace=True)

# %%
df.head()
# Out:
#    country state name product & type currency market_type quantity  month  \
# 0  Algeria    Algiers  Rice - Retail      DZD      Retail       KG      4
# 1  Algeria    Algiers  Rice - Retail      DZD      Retail       KG      5
# 2  Algeria    Algiers  Rice - Retail      DZD      Retail       KG      6
# 3  Algeria    Algiers  Rice - Retail      DZD      Retail       KG      7
# 4  Algeria    Algiers  Rice - Retail      DZD      Retail       KG      8
#
#    year  price
# 0  2015   90.0
# 1  2015   96.0
# 2  2015   96.0
# 3  2015   83.0
# 4  2015   80.0

# %%
df.country
# Out:
# 0          Algeria
# 1          Algeria
# 2          Algeria
# 3          Algeria
# 4          Algeria
#             ...
# 956774    Zimbabwe
# 956775    Zimbabwe
# 956776    Zimbabwe
# 956777    Zimbabwe
# 956778    Zimbabwe
# Name: country, Length: 956779, dtype: object

# %%
df.country.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Burundi', 'Cameroon', 'Cape Verde',
#        'Central African Republic', 'Chad', 'Congo', 'Djibouti', 'Egypt',
#        'Eritrea', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea',
#        'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mozambique',
#        'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone',
#        'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Swaziland',
#        'Togo', 'Uganda', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
df.describe()
# Out:
#                month           year         price
# count  956779.000000  956779.000000  9.567790e+05
# mean        6.381471    2015.704015  4.128833e+03
# std         3.418025       4.603829  1.381840e+05
# min         1.000000    1990.000000  0.000000e+00
# 25%         3.000000    2013.000000  6.500000e+01
# 50%         6.000000    2017.000000  2.505714e+02
# 75%         9.000000    2020.000000  7.221005e+02
# max        12.000000    2021.000000  1.725000e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         956779 non-null  object
#  1   state name      956779 non-null  object
#  2   product & type  956779 non-null  object
#  3   currency        956779 non-null  object
#  4   market_type     956779 non-null  object
#  5   quantity        956779 non-null  object
#  6   month           956779 non-null  int64
#  7   year            956779 non-null  int64
#  8   price           956779 non-null  float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 65.7+ MB

# %%
df['price'].mean()
# Out:
# 4128.833402575833

# %%
df['price'].median()
# Out:
# 250.5714

# %%
ax = df['price'].plot(kind='hist', figsize=(14,6))

# %%
corr = df.corr()
corr
# Out:
#           month      year     price
# month  1.000000 -0.075765 -0.000022
# year  -0.075765  1.000000 -0.005776
# price -0.000022 -0.005776  1.000000

# %%
boxplot_cols = ['year', 'price', 'month']
df[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(14,8))
# Out:
# year        AxesSubplot(0.125,0.536818;0.227941x0.343182)
# price    AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# month    AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# dtype: object

# %%
df.plot (kind = 'scatter', x='price', y='year', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='price', ylabel='year'>

# %%
country_df = df.groupby('country')

# %%
country_df.first()
# Out:
#                                     state name  \
# country
# Algeria                                Algiers
# Angola                                  Luanda
# Benin                         Malanville (CBM)
# Burundi                                Musenyi
# Cameroon                         Batoua Godolé
# Cape Verde                            Santiago
# Central African Republic                 Ndélé
# Chad                          National Average
# Congo                                    Nkayi
# Djibouti                            Ali Sabieh
# Egypt                         National Average
# Eritrea                                 Asmara
# Ethiopia                           Addis Ababa
# Gabon                               Libreville
# Gambia                                 Bansang
# Ghana                                   Kumasi
# Guinea                                Koundara
# Guinea-Bissau                         Kirintim
# Kenya                                  Mombasa
# ...

# %%
country_df = df.groupby('market_type')

# %%
country_df.first()
# Out:
#                 country           state name           product & type  \
# market_type
# Producer     Madagascar  Atsinanana (Region)  Rice (paddy) - Producer
# Retail          Algeria              Algiers            Rice - Retail
# Wholesale         Benin     Malanville (CBM)        Maize - Wholesale
#
#             currency quantity  month  year  price
# market_type
# Producer         MGA       KG      4  2011  950.0
# Retail           DZD       KG      4  2015   90.0
# Wholesale        XOF       KG      1  2002  145.0

# %%
country_df = df.groupby('year')

# %%
country_df.first()
# Out:
#          country        state name             product & type currency  \
# year
# 1990       Niger    Agadez Commune   Rice (imported) - Retail      XOF
# 1991       Niger    Agadez Commune   Rice (imported) - Retail      XOF
# 1992  Mozambique            Chokwe     Maize (white) - Retail      MZN
# 1993  Mozambique            Chokwe     Maize (white) - Retail      MZN
# 1994  Mozambique         Montepuez     Maize (white) - Retail      MZN
# 1995  Mozambique         Montepuez     Maize (white) - Retail      MZN
# 1996  Mozambique         Montepuez     Maize (white) - Retail      MZN
# 1997  Mozambique         Montepuez     Maize (white) - Retail      MZN
# 1998  Mozambique         Montepuez     Maize (white) - Retail      MZN
# 1999  Mozambique         Montepuez     Maize (white) - Retail      MZN
# 2000    Ethiopia       Addis Ababa  Maize (white) - Wholesale      ETB
# 2001    Ethiopia       Addis Ababa  Maize (white) - Wholesale      ETB
# ...

# %%
df.loc[24]
# Out:
# country                  Algeria
# state name               Algiers
# product & type    Bread - Retail
# currency                     DZD
# market_type               Retail
# quantity                    Unit
# month                         12
# year                        2015
# price                       10.0
# Name: 24, dtype: object

# %%
df
# Out:
#          country  state name           product & type currency market_type  \
# 0        Algeria     Algiers            Rice - Retail      DZD      Retail
# 1        Algeria     Algiers            Rice - Retail      DZD      Retail
# 2        Algeria     Algiers            Rice - Retail      DZD      Retail
# 3        Algeria     Algiers            Rice - Retail      DZD      Retail
# 4        Algeria     Algiers            Rice - Retail      DZD      Retail
# ...          ...         ...                      ...      ...         ...
# 956774  Zimbabwe  Mbilashaba   Beans (sugar) - Retail      ZWL      Retail
# 956775  Zimbabwe  Mbilashaba      Toothpaste - Retail      ZWL      Retail
# 956776  Zimbabwe  Mbilashaba    Laundry soap - Retail      ZWL      Retail
# 956777  Zimbabwe  Mbilashaba   Handwash soap - Retail      ZWL      Retail
# 956778  Zimbabwe  Mbilashaba  Fish (kapenta) - Retail      ZWL      Retail
#
#        quantity  month  year      price
# ...

# %%
df.value_counts()
# Out:
# country   state name        product & type        currency  market_type  quantity  month  year  price
# Algeria   Algiers           Apples - Retail       DZD       Retail       KG        1      2016  290.0000      1
# Nigeria   Kaura Namoda      Millet - Wholesale    NGN       Wholesale    100 KG    7      2016  11220.0000    1
#                                                                                    5      2015  5140.0000     1
#                                                                                           2016  9960.0000     1
#                                                                                           2017  16720.0000    1
#                                                                                                              ..
# Kenya     Moroto (Mombasa)  Wheat flour - Retail  KES       Retail       KG        3      2021  65.0000       1
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=956779, step=1)

# %%
len(df)
# Out:
# 956779

# %%
country_count = df.country.value_counts()
country_count
# Out:
# Rwanda                      137746
# Mali                         73843
# Burundi                      60921
# Gambia                       56971
# Niger                        54974
# Nigeria                      50285
# Zambia                       42793
# Mozambique                   42278
# Libya                        41207
# Benin                        39530
# Senegal                      33563
# Ghana                        25414
# Ethiopia                     24627
# Malawi                       22682
# Cameroon                     22476
# Guinea-Bissau                19796
# Chad                         18896
# Somalia                      18444
# South Sudan                  17746
# Central African Republic     12720
# Liberia                      12302
# Guinea                       11810
# Sierra Leone                 11645
# Zimbabwe                     10957
# Mauritania                   10871
# Sudan                         9890
# Lesotho                       9364
# ...

# %%
country_count.plot(kind='bar', figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
df['market_type'].value_counts().plot(kind='pie', autopct="%0.2f%%")
# Out:
# <AxesSubplot:ylabel='market_type'>

# %%
plt.figure(figsize=(10,6))
df['country'].value_counts().plot(kind='pie', autopct="%0.2f%%")
# Out:
# <AxesSubplot:ylabel='country'>

# %%
x = df["price"]
y = df["market_type"]

# %%
plt.scatter(x,y)

# %%
x = df["price"]
y = df["month"]

# %%
plt.scatter(x,y)

# %%
df.columns
# Out:
# Index(['country', 'state name', 'product & type', 'currency', 'market_type',
#        'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %%
sns.catplot(data=df)

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (10,6))
sns.scatterplot(data=df, y='price', x='month')
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
sns.catplot(data=df, kind='bar',y='price',x='month')

# %%
x = df["price"]
y = df["country"]
